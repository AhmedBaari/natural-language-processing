# %% [markdown]
# 1. List out the sentences from the dataframe

# %%
import pandas as pd
import numpy as np
from nltk.util import bigrams
from nltk.corpus import stopwords   
from nltk.tokenize import word_tokenize
import string
from collections import defaultdict

# %%
df = pd.read_csv("../sastralines.csv")
df
# Out:
#           Sastra University is located in Tamil Nadu.
# 0   Students at Sastra University engage in rigoro...
# 1   The university's main campus, Sastra Tanjore, ...
# 2   Sastra University offers undergraduate and pos...
# 3   Sastra University's commitment to quality educ...
# 4   The university's reputation for excellence ext...
# 5   Sastra University emphasizes a holistic approa...
# 6   Many aspiring engineers choose Sastra Universi...
# 7   The alumni network of Sastra University is a v...
# 8    The university's vision is to be a global lea...
# 9   Sastra University collaborates with industry l...
# 10  The Department of Computer Science at Sastra U...
# 11  Sastra University has been consistently ranked...
# 12   The campus life at Sastra University is vibra...
# 13  The university's commitment to research is evi...
# 14  Sastra University provides students with a con...
# 15   The annual cultural fest at Sastra University...
# 16  Sastra University's library is a hub of knowle...
# 17  The University's motto, "Knowledge is Power," ...
# 18  Sastra University promotes student involvement...
# 19  Sastra University stands out for its emphasis ...
# 20  The university's leadership is dedicated to fo...
# 21  Sastra University encourages students to parti...
# 22   Department of Business Administration at Sast...
# 23  Sastra University actively engages in corporat...
# 24  The university's commitment to social responsi...
# 25  Sastra University's campus infrastructure faci...
# 26  The university's admission process is highly c...
# 27  Sastra University has a comprehensive approach...
# 28  The faculty at Sastra University is composed o...
# 29  Sastra University's alumni make significant co...
# 30  The university's commitment to sustainable pra...
# 31  Sastra University organizes seminars and confe...
# 32  The university's sports facilities cater to a ...
# 33  Sastra University's focus on research extends ...
# 34  The university's annual convocation ceremony i...
# 35  Sastra University prides itself on its strong ...
# 36  The university's leadership encourages an incl...
# 37  Sastra University's emphasis on ethics and val...
# 38  The university's strategic partnerships enhanc...
# 39  Sastra University alumni excel in both nationa...
# 40  The university's commitment to student welfare...
# 41  Sastra University promotes a culture of contin...
# 42   The university's admission criteria are trans...
# 43  Sastra University actively engages with indust...
# 44  The university's research centers address cont...
# 45  Sastra University's campus is known for its ec...
# 46  The university's academic calendar is well-str...
# 47  Sastra University's annual technical symposium...
# 48  The university's efforts towards skill develop...

# %%
lines = df.iloc[:,0].tolist() #pandas series
lines[:5]
# Out:
# ['Students at Sastra University engage in rigorous academic pursuits.',
#  "The university's main campus, Sastra Tanjore, is known for its scenic beauty.",
#  'Sastra University offers undergraduate and postgraduate programs in diverse disciplines.',
#  "Sastra University's commitment to quality education is evident in its faculty.",
#  "The university's reputation for excellence extends beyond national borders."]

# %%
unigramD = defaultdict(int)
bigramD = defaultdict(int)

N = 0 # Wordcount
for line in lines:
    
    tokens = [i for i in word_tokenize(line.lower()) if i not in set(stopwords.words("english")) and i not in string.punctuation]
    
    for j in tokens:
        unigramD[j] += 1
        N+= 1
    for j in list(bigrams(tokens)):
        bigramD[j] += 1

# %% [markdown]
# 4. Input words, critical value

# %%
w1 = "sastra"
w2 = "university"
c = 2.0

# %% [markdown]
# 5. O,E

# %%
import math

# %%
O = bigramD[(w1,w2)]/N 
E = unigramD[(w1)]/N * unigramD[(w2)]/N 
variance = E

score = (O-E)/math.sqrt(variance/N)
O,E,score
# Out:
# (0.08401084010840108, 0.011875647211756669, 12.715450067040848)

# %%
if score > c:
    print("Reject Ho")
else:
    print("Accept Ho")
# Out:
# Reject Ho
