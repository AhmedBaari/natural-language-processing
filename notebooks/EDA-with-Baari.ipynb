# %% [markdown]
# Ahmed Baari / 126156004 / H 02

# %% [markdown]
# ## Exploratory Data Analysis of Breast Cancer Wisconsin (Diagnostic) Data Set

# %%
import pandas as pd
import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, RocCurveDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import seaborn as sns

# %%
df = pd.read_csv('breastcancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop('id', axis=1, inplace=True)

# %%
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
y.head()
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: diagnosis, dtype: object

# %% [markdown]
# ## EDA

# %% [markdown]
# ### 1. Shape of Dataset

# %%
df.shape
# Out:
# (569, 32)

# %% [markdown]
# ### 2. Head and Tail of Dataframe

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
df.tail()
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      symmetry_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %% [markdown]
# #### Distribution of each attribute

# %%
df.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<Axes: title={'center': 'radius_mean'}>,
#         <Axes: title={'center': 'texture_mean'}>,
#         <Axes: title={'center': 'perimeter_mean'}>,
#         <Axes: title={'center': 'area_mean'}>,
#         <Axes: title={'center': 'smoothness_mean'}>,
#         <Axes: title={'center': 'compactness_mean'}>],
#        [<Axes: title={'center': 'concavity_mean'}>,
#         <Axes: title={'center': 'concave points_mean'}>,
#         <Axes: title={'center': 'symmetry_mean'}>,
#         <Axes: title={'center': 'fractal_dimension_mean'}>,
#         <Axes: title={'center': 'radius_se'}>,
#         <Axes: title={'center': 'texture_se'}>],
#        [<Axes: title={'center': 'perimeter_se'}>,
#         <Axes: title={'center': 'area_se'}>,
#         <Axes: title={'center': 'smoothness_se'}>,
#         <Axes: title={'center': 'compactness_se'}>,
#         <Axes: title={'center': 'concavity_se'}>,
#         <Axes: title={'center': 'concave points_se'}>],
# ...

# %% [markdown]
# ### 3. Correlation Matrix

# %%
# convert the diagnosis column in the dataframe from string to binary
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# %%
corr_matrix = df.iloc[:100,:].corr()
# sns.pairplot(df.iloc[:10,:]) # taking forever
corr_matrix
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean  \
# diagnosis                 1.000000     0.657726      0.490952        0.675512
# radius_mean               0.657726     1.000000      0.375781        0.996356
# texture_mean              0.490952     0.375781      1.000000        0.383001
# perimeter_mean            0.675512     0.996356      0.383001        1.000000
# area_mean                 0.626511     0.991273      0.360580        0.987973
# smoothness_mean           0.282187     0.010170      0.037240        0.062334
# compactness_mean          0.560873     0.439257      0.244857        0.507818
# concavity_mean            0.623978     0.573657      0.292140        0.628943
# concave points_mean       0.714925     0.771706      0.302348        0.812203
# symmetry_mean             0.271580     0.127096     -0.031982        0.179525
# fractal_dimension_mean    0.053827    -0.286516     -0.088760       -0.217976
# ...

# %% [markdown]
# ### 4. Heatmap

# %%
sns.heatmap(corr_matrix, annot=False)
# Out:
# <Axes: >

# %% [markdown]
# ### 5. Box Plot

# %%
df.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# ### 6. Datatypes

# %%
df.dtypes
# Out:
# diagnosis                    int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# ...

# %% [markdown]
# ## Null Values

# %%
df.isna().sum()
# Out:
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# ...

# %% [markdown]
# ### 10. Statistical Summary

# %%
df.describe()
# Out:
#         diagnosis  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  569.000000   569.000000    569.000000      569.000000   569.000000
# mean     0.372583    14.127292     19.289649       91.969033   654.889104
# std      0.483918     3.524049      4.301036       24.298981   351.914129
# min      0.000000     6.981000      9.710000       43.790000   143.500000
# 25%      0.000000    11.700000     16.170000       75.170000   420.300000
# 50%      0.000000    13.370000     18.840000       86.240000   551.100000
# 75%      1.000000    15.780000     21.800000      104.100000   782.700000
# max      1.000000    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# # line plot

# %%
# line plot of radius_mean, arranged in ascending order
df['radius_mean'].sort_values().reset_index(drop=True).plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Bar Graph

# %%
# Bar plot of diagnosis
df['diagnosis'].value_counts().plot(kind='bar', color=['salmon', 'lightblue'], title='Diagnosis count', xlabel='Diagnosis', ylabel='Count')
# Out:
# <Axes: title={'center': 'Diagnosis count'}, xlabel='Diagnosis', ylabel='Count'>

# %% [markdown]
# ## Pie Chart

# %%
## pie chart of diagnosis
df['diagnosis'].value_counts().plot(kind='pie', autopct='%1.1f%%', labels=['Benign', 'Malignant'], title='Diagnosis count')
# Out:
# <Axes: title={'center': 'Diagnosis count'}, ylabel='count'>

# %% [markdown]
# ## Violin Plot

# %%
## violin plot 
sns.violinplot(x='diagnosis', y='radius_mean', data=df)
# Out:
# <Axes: xlabel='diagnosis', ylabel='radius_mean'>
